# %%
import pandas as pd

# %%
dfclientes = pd.read_excel('caso_estudo.xlsx', sheet_name = 'clientes')
dflojas = pd.read_excel('caso_estudo.xlsx', sheet_name = 'lojas')
dfprodutos = pd.read_excel('caso_estudo.xlsx', sheet_name = 'produtos')
dfpagamentos = pd.read_excel('caso_estudo.xlsx', sheet_name = 'pagamentos')
dfvendas = pd.read_excel('caso_estudo.xlsx', sheet_name = 'vendas')

# %%
dfclientes.isnull().sum()
# Out:
# id         0
# nome       4
# sexo       4
# dt_nasc    4
# dtype: int64

# %%
dfclientes[dfclientes.isnull().T.any()]
# Out:
#       id               nome sexo     dt_nasc
# 263  264                NaN    F   7/29/1997
# 264  265                NaN    M    2/7/1979
# 268  269                NaN    F         NaN
# 269  270                NaN    M         NaN
# 276  277      Brenda Santos    F         NaN
# 282  283      Amanda Barros    F         NaN
# 287  288     Victor Ribeiro  NaN  12/17/1974
# 290  291        Clara Pinto  NaN  12/25/1980
# 294  295         Tiago Lima  NaN   7/26/1973
# 301  302  Guilherme Cardoso  NaN    3/9/1998

# %% [markdown]
# # DATA CLEANNING #

# %% [markdown]
# ## Dados Nulos

# %%
dfclientes.loc[dfclientes.nome.isnull(), 'nome']= 'sem nome'
dfclientes.loc[dfclientes.sexo.isnull(), 'sexo']= 'o'
dfclientes.loc[dfclientes.dt_nasc.isnull(), 'dt_nasc']= '1/1/2020'

# %% [markdown]
# # Outliers

# %%
dfprodutos.loc[9,'valor'] = dfprodutos.valor[9]/10000

# %%
dfprodutos
# Out:
#    id        produto      valor
# 0   1          mouse    20.0000
# 1   2        teclado    30.0000
# 2   3  laptop básico  2300.0000
# 3   4   laptop gamer  5300.0000
# 4   5        monitor  1500.0000
# 5   6     impressora   700.0000
# 6   7     carregador   150.0000
# 7   8        cadeira   540.0000
# 8   9           mesa   860.0000
# 9  10       xxx-231a   321.1352

# %% [markdown]
# # Consistencia

# %%
dfvendas[~dfvendas.id_cliente.isin(dfclientes.id)]
# Out:
# Empty DataFrame
# Columns: [id, id_cliente, id_loja, id_produto, dt_venda]
# Index: []

# %% [markdown]
# # Buscando dados Duplicados

# %%
dfclientes[dfclientes.nome.duplicated()]
# Out:
#        id                nome sexo     dt_nasc
# 79     80           Anna Melo    F   8/10/1999
# 96     97  Beatrice Goncalves    F  11/22/1964
# 138   139         Kauê Araujo    M   5/31/1974
# 139   140        Leonor Sousa    F    8/2/1981
# 154   155      Luis Rodrigues    M    7/3/1973
# ..    ...                 ...  ...         ...
# 986   987     Beatriz Cardoso    F   7/17/1984
# 990   991          Diogo Melo    M   7/24/2001
# 993   994       Eduardo Costa    M  12/18/1963
# 996   997      Laura Oliveira    F   6/15/1979
# 999  1000     Gustavo Barbosa    M  12/30/1975
#
# [109 rows x 4 columns]

# %%
dfclientes.drop('id', axis = 1).duplicated().sum()
# Out:
# 0

# %%
dfprodutos.produto.duplicated().sum()
# Out:
# 0

# %%
dfvendas.duplicated().sum()
# Out:
# 0

# %%
dfvendas[dfvendas.drop('id', axis =1).duplicated()]
# Out:
#       id  id_cliente  id_loja  id_produto   dt_venda
# 496  497         559        2           5 2018-06-22

# %% [markdown]
# # Formatando Dados

# %%
dfclientes.dt_nasc = pd.to_datetime(dfclientes.dt_nasc, format = '%m/%d/%Y')

# %%
dfclientes
# Out:
#        id               nome sexo    dt_nasc
# 0       1      Lavinia Sousa    F 1975-05-02
# 1       2       Caio Pereira    M 1978-04-16
# 2       3      Júlio Azevedo    M 1952-11-04
# 3       4    Sarah Goncalves    F 1937-02-24
# 4       5  Gabrielle Martins    F 1953-05-06
# ..    ...                ...  ...        ...
# 995   996     Ágatha Ribeiro    F 1946-02-08
# 996   997     Laura Oliveira    F 1979-06-15
# 997   998      Lara Oliveira    F 1946-03-15
# 998   999       Julian Cunha    M 1994-06-20
# 999  1000    Gustavo Barbosa    M 1975-12-30
#
# [1000 rows x 4 columns]

# %% [markdown]
# # Definindo Index

# %%
dfclientes = dfclientes.set_index('id')

# %%
dfpagamentos = dfpagamentos.set_index('id')

# %%
dfvendas = dfvendas.set_index('id')

# %%
dflojas = dflojas.set_index('id')

# %%
dfprodutos = dfprodutos.set_index('id')

# %% [markdown]
# # Data Fusion

# %%
df = dfvendas.join(dfclientes.add_prefix('cliente_'), on ='id_cliente')

# %%
df
# Out:
#       id_cliente  id_loja  id_produto   dt_venda     cliente_nome  \
# id
# 1            393        9           3 2018-01-04    Gustavo Silva
# 2            417        9           3 2018-01-04   Leonor Almeida
# 3            374        7           8 2018-01-04      André Alves
# 4             59        4           3 2018-01-05  Rodrigo Ribeiro
# 5             18        9           1 2018-01-05  Antônio Azevedo
# ...          ...      ...         ...        ...              ...
# 2996         671        3           7 2020-09-27    Ana Goncalves
# 2997         586        8           3 2020-09-27      Aline Pinto
# 2998         731        2           4 2020-09-27     Otávio Silva
# 2999         163        2           1 2020-09-27      Ana Pereira
# 3000         770        2           2 2020-09-27  Beatrice Castro
#
#      cliente_sexo cliente_dt_nasc
# id
# 1               M      1950-01-04
# 2               F      1972-01-31
# 3               M      1962-08-03
# 4               M      1941-11-05
# 5               M      1941-04-15
# ...           ...             ...
# 2996            F      1999-10-31
# 2997            F      1994-03-29
# 2998            M      1986-05-04
# 2999            F      1967-01-10
# 3000            F      1944-06-25
#
# [3000 rows x 7 columns]

# %%
df = df.join(dflojas.add_prefix('loja_'), on = 'id_loja')

# %%
df = df.join(dfprodutos.add_prefix('prod_'), on = 'id_produto')

# %%
df
# Out:
#       id_cliente  id_loja  id_produto   dt_venda     cliente_nome  \
# id
# 1            393        9           3 2018-01-04    Gustavo Silva
# 2            417        9           3 2018-01-04   Leonor Almeida
# 3            374        7           8 2018-01-04      André Alves
# 4             59        4           3 2018-01-05  Rodrigo Ribeiro
# 5             18        9           1 2018-01-05  Antônio Azevedo
# ...          ...      ...         ...        ...              ...
# 2996         671        3           7 2020-09-27    Ana Goncalves
# 2997         586        8           3 2020-09-27      Aline Pinto
# 2998         731        2           4 2020-09-27     Otávio Silva
# 2999         163        2           1 2020-09-27      Ana Pereira
# 3000         770        2           2 2020-09-27  Beatrice Castro
#
#      cliente_sexo cliente_dt_nasc     loja_cidade   prod_produto  prod_valor
# id
# 1               M      1950-01-04          Palmas  laptop básico      2300.0
# 2               F      1972-01-31          Palmas  laptop básico      2300.0
# 3               M      1962-08-03        Salvador        cadeira       540.0
# 4               M      1941-11-05  Belo Horizonte  laptop básico      2300.0
# 5               M      1941-04-15          Palmas          mouse        20.0
# ...           ...             ...             ...            ...         ...
# 2996            F      1999-10-31        Curitiba     carregador       150.0
# 2997            F      1994-03-29        Brasília  laptop básico      2300.0
# 2998            M      1986-05-04  Rio de Janeiro   laptop gamer      5300.0
# 2999            F      1967-01-10  Rio de Janeiro          mouse        20.0
# 3000            F      1944-06-25  Rio de Janeiro        teclado        30.0
#
# [3000 rows x 10 columns]

# %%
df = df.join(dfpagamentos.set_index('id_venda'))

# %%
df
# Out:
#       id_cliente  id_loja  id_produto   dt_venda     cliente_nome  \
# id
# 1            393        9           3 2018-01-04    Gustavo Silva
# 2            417        9           3 2018-01-04   Leonor Almeida
# 3            374        7           8 2018-01-04      André Alves
# 4             59        4           3 2018-01-05  Rodrigo Ribeiro
# 5             18        9           1 2018-01-05  Antônio Azevedo
# ...          ...      ...         ...        ...              ...
# 2996         671        3           7 2020-09-27    Ana Goncalves
# 2997         586        8           3 2020-09-27      Aline Pinto
# 2998         731        2           4 2020-09-27     Otávio Silva
# 2999         163        2           1 2020-09-27      Ana Pereira
# 3000         770        2           2 2020-09-27  Beatrice Castro
#
#      cliente_sexo cliente_dt_nasc     loja_cidade   prod_produto  prod_valor  \
# id
# 1               M      1950-01-04          Palmas  laptop básico      2300.0
# 2               F      1972-01-31          Palmas  laptop básico      2300.0
# 3               M      1962-08-03        Salvador        cadeira       540.0
# 4               M      1941-11-05  Belo Horizonte  laptop básico      2300.0
# 5               M      1941-04-15          Palmas          mouse        20.0
# ...           ...             ...             ...            ...         ...
# 2996            F      1999-10-31        Curitiba     carregador       150.0
# 2997            F      1994-03-29        Brasília  laptop básico      2300.0
# 2998            M      1986-05-04  Rio de Janeiro   laptop gamer      5300.0
# 2999            F      1967-01-10  Rio de Janeiro          mouse        20.0
# 3000            F      1944-06-25  Rio de Janeiro        teclado        30.0
#
#         dt_pgto
# id
# 1    2018-01-24
# 2    2018-02-17
# 3    2018-02-14
# 4           NaT
# 5    2018-01-23
# ...         ...
# 2996 2020-10-17
# 2997 2020-10-02
# 2998        NaT
# 2999        NaT
# 3000        NaT
#
# [3000 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# id_cliente           0
# id_loja              0
# id_produto           0
# dt_venda             0
# cliente_nome         0
# cliente_sexo         0
# cliente_dt_nasc      0
# loja_cidade          0
# prod_produto         0
# prod_valor           0
# dt_pgto            928
# dtype: int64

# %%
df.loc[df.cliente_sexo.isnull(), 'cliente_sexo']= 'o'
df.loc[df.cliente_dt_nasc.isnull(), 'cliente_dt_nasc']= '1/1/2020'

# %%
df.isnull().sum()
# Out:
# id_cliente           0
# id_loja              0
# id_produto           0
# dt_venda             0
# cliente_nome         0
# cliente_sexo         0
# cliente_dt_nasc      0
# loja_cidade          0
# prod_produto         0
# prod_valor           0
# dt_pgto            928
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
df
# Out:
#       id_cliente  id_loja  id_produto   dt_venda     cliente_nome  \
# id
# 1            393        9           3 2018-01-04    Gustavo Silva
# 2            417        9           3 2018-01-04   Leonor Almeida
# 3            374        7           8 2018-01-04      André Alves
# 4             59        4           3 2018-01-05  Rodrigo Ribeiro
# 5             18        9           1 2018-01-05  Antônio Azevedo
# ...          ...      ...         ...        ...              ...
# 2996         671        3           7 2020-09-27    Ana Goncalves
# 2997         586        8           3 2020-09-27      Aline Pinto
# 2998         731        2           4 2020-09-27     Otávio Silva
# 2999         163        2           1 2020-09-27      Ana Pereira
# 3000         770        2           2 2020-09-27  Beatrice Castro
#
#      cliente_sexo      cliente_dt_nasc     loja_cidade   prod_produto  \
# id
# 1               M  1950-01-04 00:00:00          Palmas  laptop básico
# 2               F  1972-01-31 00:00:00          Palmas  laptop básico
# 3               M  1962-08-03 00:00:00        Salvador        cadeira
# 4               M  1941-11-05 00:00:00  Belo Horizonte  laptop básico
# 5               M  1941-04-15 00:00:00          Palmas          mouse
# ...           ...                  ...             ...            ...
# 2996            F  1999-10-31 00:00:00        Curitiba     carregador
# 2997            F  1994-03-29 00:00:00        Brasília  laptop básico
# 2998            M  1986-05-04 00:00:00  Rio de Janeiro   laptop gamer
# 2999            F  1967-01-10 00:00:00  Rio de Janeiro          mouse
# 3000            F  1944-06-25 00:00:00  Rio de Janeiro        teclado
#
#       prod_valor    dt_pgto
# id
# 1         2300.0 2018-01-24
# 2         2300.0 2018-02-17
# 3          540.0 2018-02-14
# 4         2300.0        NaT
# 5           20.0 2018-01-23
# ...          ...        ...
# 2996       150.0 2020-10-17
# 2997      2300.0 2020-10-02
# 2998      5300.0        NaT
# 2999        20.0        NaT
# 3000        30.0        NaT
#
# [3000 rows x 11 columns]

# %%
df['pago'] = 1

# %%
df
# Out:
#       id_cliente  id_loja  id_produto   dt_venda     cliente_nome  \
# id
# 1            393        9           3 2018-01-04    Gustavo Silva
# 2            417        9           3 2018-01-04   Leonor Almeida
# 3            374        7           8 2018-01-04      André Alves
# 4             59        4           3 2018-01-05  Rodrigo Ribeiro
# 5             18        9           1 2018-01-05  Antônio Azevedo
# ...          ...      ...         ...        ...              ...
# 2996         671        3           7 2020-09-27    Ana Goncalves
# 2997         586        8           3 2020-09-27      Aline Pinto
# 2998         731        2           4 2020-09-27     Otávio Silva
# 2999         163        2           1 2020-09-27      Ana Pereira
# 3000         770        2           2 2020-09-27  Beatrice Castro
#
#      cliente_sexo      cliente_dt_nasc     loja_cidade   prod_produto  \
# id
# 1               M  1950-01-04 00:00:00          Palmas  laptop básico
# 2               F  1972-01-31 00:00:00          Palmas  laptop básico
# 3               M  1962-08-03 00:00:00        Salvador        cadeira
# 4               M  1941-11-05 00:00:00  Belo Horizonte  laptop básico
# 5               M  1941-04-15 00:00:00          Palmas          mouse
# ...           ...                  ...             ...            ...
# 2996            F  1999-10-31 00:00:00        Curitiba     carregador
# 2997            F  1994-03-29 00:00:00        Brasília  laptop básico
# 2998            M  1986-05-04 00:00:00  Rio de Janeiro   laptop gamer
# 2999            F  1967-01-10 00:00:00  Rio de Janeiro          mouse
# 3000            F  1944-06-25 00:00:00  Rio de Janeiro        teclado
#
#       prod_valor    dt_pgto  pago
# id
# 1         2300.0 2018-01-24     1
# 2         2300.0 2018-02-17     1
# 3          540.0 2018-02-14     1
# 4         2300.0        NaT     1
# 5           20.0 2018-01-23     1
# ...          ...        ...   ...
# 2996       150.0 2020-10-17     1
# 2997      2300.0 2020-10-02     1
# 2998      5300.0        NaT     1
# 2999        20.0        NaT     1
# 3000        30.0        NaT     1
#
# [3000 rows x 12 columns]

# %%
df.loc[df.dt_pgto.isnull(), 'pago'] = 0

# %%
df['temp_pago'] = (df.dt_pgto - df.dt_venda).dt.days

# %%
df
# Out:
#       id_cliente  id_loja  id_produto   dt_venda     cliente_nome  \
# id
# 1            393        9           3 2018-01-04    Gustavo Silva
# 2            417        9           3 2018-01-04   Leonor Almeida
# 3            374        7           8 2018-01-04      André Alves
# 4             59        4           3 2018-01-05  Rodrigo Ribeiro
# 5             18        9           1 2018-01-05  Antônio Azevedo
# ...          ...      ...         ...        ...              ...
# 2996         671        3           7 2020-09-27    Ana Goncalves
# 2997         586        8           3 2020-09-27      Aline Pinto
# 2998         731        2           4 2020-09-27     Otávio Silva
# 2999         163        2           1 2020-09-27      Ana Pereira
# 3000         770        2           2 2020-09-27  Beatrice Castro
#
#      cliente_sexo      cliente_dt_nasc     loja_cidade   prod_produto  \
# id
# 1               M  1950-01-04 00:00:00          Palmas  laptop básico
# 2               F  1972-01-31 00:00:00          Palmas  laptop básico
# 3               M  1962-08-03 00:00:00        Salvador        cadeira
# 4               M  1941-11-05 00:00:00  Belo Horizonte  laptop básico
# 5               M  1941-04-15 00:00:00          Palmas          mouse
# ...           ...                  ...             ...            ...
# 2996            F  1999-10-31 00:00:00        Curitiba     carregador
# 2997            F  1994-03-29 00:00:00        Brasília  laptop básico
# 2998            M  1986-05-04 00:00:00  Rio de Janeiro   laptop gamer
# 2999            F  1967-01-10 00:00:00  Rio de Janeiro          mouse
# 3000            F  1944-06-25 00:00:00  Rio de Janeiro        teclado
#
#       prod_valor    dt_pgto  pago  temp_pago
# id
# 1         2300.0 2018-01-24     1       20.0
# 2         2300.0 2018-02-17     1       44.0
# 3          540.0 2018-02-14     1       41.0
# 4         2300.0        NaT     0        NaN
# 5           20.0 2018-01-23     1       18.0
# ...          ...        ...   ...        ...
# 2996       150.0 2020-10-17     1       20.0
# 2997      2300.0 2020-10-02     1        5.0
# 2998      5300.0        NaT     0        NaN
# 2999        20.0        NaT     0        NaN
# 3000        30.0        NaT     0        NaN
#
# [3000 rows x 13 columns]

# %%
import numpy as np
np.floor((pd.to_datetime('today') - df.cliente_dt_nasc)/np.timedelta64(1,'Y'))
# Out:
# id
# 1       71.0
# 2       49.0
# 3       58.0
# 4       79.0
# 5       80.0
#         ...
# 2996    21.0
# 2997    27.0
# 2998    34.0
# 2999    54.0
# 3000    76.0
# Name: cliente_dt_nasc, Length: 3000, dtype: float64

# %%
df['cliente_idade'] = np.floor((pd.to_datetime('today') - df.cliente_dt_nasc)/np.timedelta64(1,'Y'))

# %%
df
# Out:
#       id_cliente  id_loja  id_produto   dt_venda     cliente_nome  \
# id
# 1            393        9           3 2018-01-04    Gustavo Silva
# 2            417        9           3 2018-01-04   Leonor Almeida
# 3            374        7           8 2018-01-04      André Alves
# 4             59        4           3 2018-01-05  Rodrigo Ribeiro
# 5             18        9           1 2018-01-05  Antônio Azevedo
# ...          ...      ...         ...        ...              ...
# 2996         671        3           7 2020-09-27    Ana Goncalves
# 2997         586        8           3 2020-09-27      Aline Pinto
# 2998         731        2           4 2020-09-27     Otávio Silva
# 2999         163        2           1 2020-09-27      Ana Pereira
# 3000         770        2           2 2020-09-27  Beatrice Castro
#
#      cliente_sexo      cliente_dt_nasc     loja_cidade   prod_produto  \
# id
# 1               M  1950-01-04 00:00:00          Palmas  laptop básico
# 2               F  1972-01-31 00:00:00          Palmas  laptop básico
# 3               M  1962-08-03 00:00:00        Salvador        cadeira
# 4               M  1941-11-05 00:00:00  Belo Horizonte  laptop básico
# 5               M  1941-04-15 00:00:00          Palmas          mouse
# ...           ...                  ...             ...            ...
# 2996            F  1999-10-31 00:00:00        Curitiba     carregador
# 2997            F  1994-03-29 00:00:00        Brasília  laptop básico
# 2998            M  1986-05-04 00:00:00  Rio de Janeiro   laptop gamer
# 2999            F  1967-01-10 00:00:00  Rio de Janeiro          mouse
# 3000            F  1944-06-25 00:00:00  Rio de Janeiro        teclado
#
#       prod_valor    dt_pgto  pago  temp_pago  cliente_idade
# id
# 1         2300.0 2018-01-24     1       20.0           71.0
# 2         2300.0 2018-02-17     1       44.0           49.0
# 3          540.0 2018-02-14     1       41.0           58.0
# 4         2300.0        NaT     0        NaN           79.0
# 5           20.0 2018-01-23     1       18.0           80.0
# ...          ...        ...   ...        ...            ...
# 2996       150.0 2020-10-17     1       20.0           21.0
# 2997      2300.0 2020-10-02     1        5.0           27.0
# 2998      5300.0        NaT     0        NaN           34.0
# 2999        20.0        NaT     0        NaN           54.0
# 3000        30.0        NaT     0        NaN           76.0
#
# [3000 rows x 14 columns]

# %% [markdown]
# # Analise

# %% [markdown]
# ## Lojas e produtos que mais vendem

# %%
cida_mais = df.groupby('loja_cidade').count().prod_valor.sort_values(ascending = False)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize =(15,5))
plt.bar(cida_mais.index, cida_mais.values)
plt.title('vendas po loja')
# Out:
# Text(0.5, 1.0, 'vendas po loja')

# %% [markdown]
# ## Produtos que mais vendem

# %%
prod_mais = df.groupby('prod_produto').count().prod_valor.sort_values(ascending = False)

# %%
prod_mais
# Out:
# prod_produto
# laptop básico    1395
# teclado           204
# impressora        191
# monitor           187
# xxx-231a          182
# laptop gamer      180
# mouse             172
# mesa              171
# carregador        164
# cadeira           154
# Name: prod_valor, dtype: int64

# %%
plt.figure(figsize =(15,5))
plt.bar(prod_mais.index, prod_mais.values)
plt.title('Produtos mais vendidos')
# Out:
# Text(0.5, 1.0, 'Produtos mais vendidos')

# %% [markdown]
# ## Receita por loja

# %%
re_loja = df[['loja_cidade', 'prod_valor']].groupby('loja_cidade').sum().prod_valor.sort_values(ascending =False)

# %%
plt.figure(figsize = (15,5))
plt.bar(re_loja.index, re_loja.values)
# Out:
# <BarContainer object of 10 artists>
